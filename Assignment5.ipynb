# %% [markdown]
# Load the iris dataset using pandas and display the first 5 rows

# %%
import pandas as pd
df_auto=pd.read_excel('/content/iris_dataset.xls')
df_auto.head()
# Out:
#     SL   SW   PL   PW Classification
# 0  5.1  3.5  1.4  0.2    Iris-setosa
# 1  4.9  3.0  1.4  0.2    Iris-setosa
# 2  4.7  3.2  1.3  0.2    Iris-setosa
# 3  4.6  3.1  1.5  0.2    Iris-setosa
# 4  5.0  3.6  1.4  0.2    Iris-setosa

# %% [markdown]
# Calculate and display the mean,median,and standard deviation of sepal lenght(cm)for the entire dataset

# %%
df_auto['SL'].mean()
# Out:
# 5.843333333333334

# %%
df_auto['SL'].median()
# Out:
# 5.8

# %%
df_auto['SL'].std()
# Out:
# 0.828066127977863

# %% [markdown]
# find the maximum value of petal width(cm) and the corresponding species(target class)

# %%
df_auto['PW'].max()
# Out:
# 2.5

# %%
df_auto['PL'].max()
# Out:
# 6.9

# %%
df_auto['SW'].max()
# Out:
# 4.4

# %% [markdown]
# use iloc to diplay the values of the first row in the dataset

# %%
df_auto.iloc[0]
# Out:
# SL                        5.1
# SW                        3.5
# PL                        1.4
# PW                        0.2
# Classification    Iris-setosa
# Name: 0, dtype: object

# %% [markdown]
# Use iloc to display all columns for the sample with index 10

# %%
df_auto.loc[:10]
# Out:
#      SL   SW   PL   PW Classification
# 0   5.1  3.5  1.4  0.2    Iris-setosa
# 1   4.9  3.0  1.4  0.2    Iris-setosa
# 2   4.7  3.2  1.3  0.2    Iris-setosa
# 3   4.6  3.1  1.5  0.2    Iris-setosa
# 4   5.0  3.6  1.4  0.2    Iris-setosa
# 5   5.4  3.9  1.7  0.4    Iris-setosa
# 6   4.6  3.4  1.4  0.3    Iris-setosa
# 7   5.0  3.4  1.5  0.2    Iris-setosa
# 8   4.4  2.9  1.4  0.2    Iris-setosa
# 9   4.9  3.1  1.5  0.1    Iris-setosa
# 10  5.4  3.7  1.5  0.2    Iris-setosa

# %% [markdown]
# Use iloc to display the values of the last row in the dataset

# %%
df_auto.iloc[-1]
# Out:
# SL                           5.9
# SW                           3.0
# PL                           5.1
# PW                           1.8
# Classification    Iris-virginica
# Name: 149, dtype: object

# %% [markdown]
# Use iloc to display the petal lenght and petal width for sample with indices 25 to 30(inclusive)

# %%
df_auto.loc[25:30,["PL"]]
# Out:
#      PL
# 25  1.6
# 26  1.6
# 27  1.5
# 28  1.4
# 29  1.6
# 30  1.6

# %%
df_auto.loc[25:30,["PW"]]
# Out:
#      PW
# 25  0.2
# 26  0.4
# 27  0.2
# 28  0.2
# 29  0.2
# 30  0.2

# %% [markdown]
# Use iloc to display the sepal lenght and sepal width for the first 10 samples

# %%
df_auto.iloc[:10,[0,1]]
# Out:
#     SL   SW
# 0  5.1  3.5
# 1  4.9  3.0
# 2  4.7  3.2
# 3  4.6  3.1
# 4  5.0  3.6
# 5  5.4  3.9
# 6  4.6  3.4
# 7  5.0  3.4
# 8  4.4  2.9
# 9  4.9  3.1

# %% [markdown]
# Use loc to display all columns for sample with target class 1

# %%
df_auto.loc[1,:]
# Out:
# SL                        4.9
# SW                        3.0
# PL                        1.4
# PW                        0.2
# Classification    Iris-setosa
# Name: 1, dtype: object
